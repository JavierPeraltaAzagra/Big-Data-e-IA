# %% [markdown]
# # Ejercicios 2 de Pandas

# %% [markdown]
# ---
# ## Ejercicio 1
# Crea un DataFrame de 20x6 con los siguientes tipos de datos:
# - Columnas numéricas con enteros y flotantes.
# - Columna de fechas aleatorias en 2025.
# - Columna categórica con valores como 'A', 'B', 'C'.
# - Columna booleana aleatoria.
# Muestra las primeras 5 filas y la estructura del DataFrame (`info()`).

# %%
import pandas as pd
import numpy as np

col_int = np.random.randint(0, 100, 20)
# Multiplico por 100 para obtener un rango más amplio y no solo entre 0 y 1
col_float = np.random.random(20) * 100
# Fechas aleatorias en 2025
fechas = pd.to_datetime(
    np.random.randint(
        # Se divide entre 10**9 para convertir de nanosegundos a segundos
        pd.Timestamp('2025-01-01').value // 10**9,
        pd.Timestamp('2025-12-31').value // 10**9,
        20
    ),
    unit='s'
)

# Choice elige aleatoriamente entre las opciones dadas
categorias = np.random.choice(['A', 'B', 'C'], size=20)
booleanos = np.random.choice([True, False], size=20)

df = pd.DataFrame({
    'Entero': col_int,
    'Float': col_float,
    'Fecha': fechas,
    'Categoría': categorias,
    'Booleano': booleanos
})

print("Primeras 5 filas:")
print(df.head(), "\n")
print("Información del DataFrame:")
print(df.info())
# Out:
# Primeras 5 filas:
#    Entero      Float               Fecha Categoría  Booleano
# 0      29  15.022449 2025-04-05 20:21:15         B      True
# 1      89  58.000491 2025-01-06 16:03:55         A     False
# 2      91  85.406137 2025-10-14 16:37:39         B     False
# 3      91  49.516554 2025-10-22 20:22:14         A      True
# 4      42  16.594292 2025-09-30 16:37:30         A     False
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Entero     20 non-null     int32
#  1   Float      20 non-null     float64
#  2   Fecha      20 non-null     datetime64[ns]
#  3   Categoría  20 non-null     object
#  4   Booleano   20 non-null     bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int32(1), object(1)
# memory usage: 708.0+ bytes
# None

# %% [markdown]
# ---
# ## Ejercicio 2
# Introduce valores nulos en aproximadamente el 15% de las celdas del DataFrame.
# - Reemplaza los nulos en columnas numéricas con la **media**.
# - Reemplaza los nulos en columnas categóricas con el **valor más frecuente**.
# - Muestra el resultado y verifica que no quedan nulos.

# %%
# *df.shape devuelve el numero de filas y columnas pero como 2 valores separados
# Como random.rand genera valores entre 0 y 1, le decimos que los menores a 0.15 sean True
# Esto crea un array booleano del mismo tamaño que df con un 15% de Trues y 85% de Falses
mask = np.random.rand(*df.shape) < 0.15
# .mask() reemplaza los valores True con NaN
df = df.mask(mask)
print(f"Df con nulos 15%:\n{df}\n")
df["Entero"] = df["Entero"].fillna(df["Entero"].mean())
df["Float"] = df["Float"].fillna(df["Float"].mean())
df["Fecha"] = df["Fecha"].fillna(df["Fecha"].mean())
df["Categoría"] = df["Categoría"].fillna(df["Categoría"].mode()[0])
df["Booleano"] = df["Booleano"].fillna(df["Booleano"].mode()[0])
print(f"Df sin nulos:\n{df}")
print(f"Nulos restantes:\n{df.isnull().sum()}")
# Out:
# Df con nulos 15%:
#     Entero      Float               Fecha Categoría  Booleano
# 0      NaN  15.022449 2025-04-05 20:21:15       NaN      True
# 1     89.0        NaN 2025-01-06 16:03:55         A     False
# 2     91.0        NaN 2025-10-14 16:37:39         B     False
# 3     91.0  49.516554 2025-10-22 20:22:14         A      True
# 4     42.0  16.594292 2025-09-30 16:37:30         A     False
# 5     66.0  92.885537                 NaT       NaN     False
# 6     72.0        NaN 2025-03-25 07:12:17         A      True
# 7     63.0  77.759748                 NaT         B     False
# 8     53.0        NaN 2025-05-13 21:58:04         C     False
# 9      3.0  39.536721 2025-09-04 23:10:33       NaN      True
# 10    67.0  87.806698 2025-08-13 00:37:29         C     False
# 11    40.0  60.214893                 NaT         B     False
# 12    80.0  32.782163 2025-10-31 06:47:58         B      True
# 13    71.0  62.446105                 NaT         B     False
# 14    19.0  69.892391 2025-08-10 19:33:17         B      True
# 15    59.0        NaN 2025-12-16 14:12:49         A     False
# 16     NaN  62.187068 2025-12-23 13:13:52       NaN     False
# 17     NaN  77.979191 2025-08-05 12:31:05         B     False
# 18    30.0  54.367574 2025-05-26 05:24:40         B      True
# 19    80.0        NaN                 NaT         A      True
#
# Df sin nulos:
#        Entero      Float                         Fecha Categoría  Booleano
# 0   59.764706  15.022449 2025-04-05 20:21:15.000000000         B      True
# 1   89.000000  57.070813 2025-01-06 16:03:55.000000000         A     False
# 2   91.000000  57.070813 2025-10-14 16:37:39.000000000         B     False
# 3   91.000000  49.516554 2025-10-22 20:22:14.000000000         A      True
# 4   42.000000  16.594292 2025-09-30 16:37:30.000000000         A     False
# 5   66.000000  92.885537 2025-08-04 15:54:58.466666752         B     False
# 6   72.000000  57.070813 2025-03-25 07:12:17.000000000         A      True
# 7   63.000000  77.759748 2025-08-04 15:54:58.466666752         B     False
# 8   53.000000  57.070813 2025-05-13 21:58:04.000000000         C     False
# 9    3.000000  39.536721 2025-09-04 23:10:33.000000000         B      True
# 10  67.000000  87.806698 2025-08-13 00:37:29.000000000         C     False
# 11  40.000000  60.214893 2025-08-04 15:54:58.466666752         B     False
# 12  80.000000  32.782163 2025-10-31 06:47:58.000000000         B      True
# 13  71.000000  62.446105 2025-08-04 15:54:58.466666752         B     False
# 14  19.000000  69.892391 2025-08-10 19:33:17.000000000         B      True
# 15  59.000000  57.070813 2025-12-16 14:12:49.000000000         A     False
# 16  59.764706  62.187068 2025-12-23 13:13:52.000000000         B     False
# 17  59.764706  77.979191 2025-08-05 12:31:05.000000000         B     False
# 18  30.000000  54.367574 2025-05-26 05:24:40.000000000         B      True
# 19  80.000000  57.070813 2025-08-04 15:54:58.466666752         A      True
# Nulos restantes:
# Entero       0
# Float        0
# Fecha        0
# Categoría    0
# Booleano     0
# dtype: int64

# %% [markdown]
# ---
# ## Ejercicio 3
# Crea un **MultiIndex** a partir de dos columnas categóricas y reorganiza el DataFrame usando este MultiIndex.
# - Muestra un resumen por grupo usando `groupby` y calcula la media de las columnas numéricas.

# %%
df = df.set_index(['Categoría', 'Booleano']).sort_index()
print(df.groupby(level=['Categoría', 'Booleano'])[['Entero', 'Float']].mean())
# Out:
#                        Entero      Float
# Categoría Booleano
# A         False     63.333333  43.578639
#           True      81.000000  54.552727
# B         False     64.361345  70.077622
#           True      38.352941  42.320259
# C         False     60.000000  72.438755

# %% [markdown]
# ---
# ## Ejercicio 4
# Crea un DataFrame de 100 filas con tres columnas numéricas.
# - Calcula la **correlación condicional** entre las columnas solo para las filas donde la columna booleana sea True.
# - Identifica la pareja de columnas con mayor correlación condicional.

# %%
col_num1 = np.random.rand(100) * 100
col_num2 = np.random.rand(100) * 100
col_num3 = np.random.rand(100) * 100
col_bool = np.random.choice([True, False], size=100)
df = pd.DataFrame({
    'Num1': col_num1,
    'Num2': col_num2,
    'Num3': col_num3,
    'Booleano': col_bool
})
df_true = df[df['Booleano'] == True]
corr_cond = df_true[['Num1', 'Num2', 'Num3']].corr()
print("Correlación condicional (True):")
print(corr_cond)
#TODO ultimo punto
# Out:
# Correlación condicional (True):
#           Num1      Num2      Num3
# Num1  1.000000  0.002700 -0.213019
# Num2  0.002700  1.000000  0.102604
# Num3 -0.213019  0.102604  1.000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 18
#      15 #TODO
#      16 # Identifica la pareja de columnas con mayor correlación condicional. sin contar la diagonal
#      17 mask = np.eye(corr_cond.shape[0], dtype=bool)
# ---> 18 max_corr = corr_cond[~mask].unstack().idxmax()
#      19 print(f"Mayor correlación condicional: {max_corr}")
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:9935, in DataFrame.unstack(self, level, fill_value, sort)
#    9871 """
#    9872 Pivot a level of the (necessarily hierarchical) index labels.
#    9873
#    (...)   9931 dtype: float64
#    9932 """
#    9933 from pandas.core.reshape.reshape import unstack
# -> 9935 result = unstack(self, level, fill_value, sort)
#    9937 return result.__finalize__(self, method="unstack")
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:506, in unstack(obj, level, fill_value, sort)
#     504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
# --> 506         return obj.T.stack(future_stack=True)
#     507 elif not isinstance(obj.index, MultiIndex):
#     508     # GH 36113
#     509     # Give nicer error messages when unstack a Series whose
#     510     # Index is not a MultiIndex.
#     511     raise ValueError(
#     512         f"index must be a MultiIndex to unstack, {type(obj.index)} was passed"
#     513     )
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:9738, in DataFrame.stack(self, level, dropna, sort, future_stack)
#    9736         level = [level]
#    9737     level = [self.columns._get_level_number(lev) for lev in level]
# -> 9738     result = stack_v3(self, level)
#    9740 return result.__finalize__(self, method="stack")
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:887, in stack_v3(frame, level)
#     885 def stack_v3(frame: DataFrame, level: list[int]) -> Series | DataFrame:
#     886     if frame.columns.nunique() != len(frame.columns):
# --> 887         raise ValueError("Columns with duplicate values are not supported in stack")
#     889     # If we need to drop `level` from columns, it needs to be in descending order
#     890     drop_levnums = sorted(level, reverse=True)
#
# ValueError: Columns with duplicate values are not supported in stack

# %% [markdown]
# ---
# ## Ejercicio 5
# Genera un DataFrame con ventas de 50 productos en 12 meses (columna 'Producto', columnas 'Mes_1' a 'Mes_12').
# - Calcula la suma anual por producto.
# - Crea una columna con la **media mensual** de cada producto.
# - Ordena el DataFrame por total anual descendente.

# %% [markdown]
# ---
# ## Ejercicio 6
# Lee un archivo CSV con al menos 500 filas y múltiples columnas (simula datos reales).
# - Muestra las 10 filas con los valores más altos de una columna específica.
# - Filtra filas que cumplan múltiples condiciones combinadas.

# %% [markdown]
# ---
# ## Ejercicio 7
# Crea un DataFrame de 30 filas con columnas numéricas y categóricas.
# - Usa `pivot_table` para obtener la media de una columna numérica por categoría.
# - Incluye un `margins=True` para obtener totales.

# %% [markdown]
# ---
# ## Ejercicio 8
# Crea un DataFrame con 100 filas, 5 columnas numéricas y 2 columnas de texto.
# - Aplica una función con `apply` que transforme los valores numéricos según una condición (por ejemplo, multiplicar por 2 si >50).
# - Aplica `applymap` a todo el DataFrame numérico para normalizar los valores entre 0 y 1.

# %% [markdown]
# ---
# ## Ejercicio 9
# Simula un escenario de base de datos:
# - Crea dos DataFrames (`clientes` y `pedidos`) con columnas de id, nombre, producto y cantidad.
# - Realiza un `merge` usando `id_cliente` para combinar información.
# - Calcula el total de pedidos por cliente.

# %% [markdown]
# ---
# ## Ejercicio 10
# Crea un DataFrame de 50 filas con columna de fechas aleatorias.
# - Agrupa por **mes y día de la semana** y calcula la media de otra columna numérica.
# - Representa la tabla resultante en un DataFrame pivotado para ver los valores organizados por mes y día.
