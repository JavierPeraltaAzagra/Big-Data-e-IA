# %%
import sys
import torch

print("Python:", sys.executable)
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Python: c:\datos\Documents\Big-Data-e-IA\Sistemas de aprendizaje automático\RA6\pytorch\pytorch-cpu\Scripts\python.exe
# PyTorch: 2.11.0+cpu
# CUDA available: False

# %%
x = torch.tensor([1, 2, 3, 4], dtype=torch.float32)

print(x)
print("Dimensión:", x.ndim)
print("Forma:", x.shape)
print("Tipo:", x.dtype)
# Out:
# tensor([1., 2., 3., 4.])
# Dimensión: 1
# Forma: torch.Size([4])
# Tipo: torch.float32
