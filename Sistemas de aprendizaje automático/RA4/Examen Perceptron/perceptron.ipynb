# %%
import numpy as np
import matplotlib.pyplot as plt

def dibujar_recta(w1, w2, b):    
    #Dibuja la recta w1*x1 + w2*x2 + b = 0
    
    plt.figure(figsize=(5,5))
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-10, 10, 100)
    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    x2 = -(w1/w2) * x1 - (b/w2)

    # Dibujamos la recta usando matplotlib
    plt.plot(x1, x2, color="red")
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(f'Recta: ${w1}x_1 + {w2}x_2 + ({b}) = 0$')
    #plt.title(r"Gráfica recta $w_1 x_1 + w_2 x_2 + b = 0$")
    plt.xlim(-2, 5) # definimos rango del eje x
    plt.ylim(-2, 7) # definimos rango del eje y
    plt.grid(True)
    # Mostramos la figura en pantalla
    plt.show()

# %%
# dibuja la recta x1 + 2x2 - 2 = 0
# w1 =
# w2 = 
# b = 
dibujar_recta(w1=5, w2=2, b=-10)
# Escribe esta recta en la forma explícita
# Encuentra su pendiente
# Encuentra el punto de la recta dónde corta el eje x2
# Investiga como cambia la recta (inclinación y desplazamiento vertical con respecto al eje x1) para diferentes valores de w1, w2 y b
# w1 y w2 afectan la inclinación de la recta, mientras que b afecta el desplazamiento vertical. Por ejemplo, si w1 aumenta, la pendiente de la recta se vuelve más pronunciada, mientras que si w2 aumenta, la pendiente se vuelve menos pronunciada. Si b aumenta, la recta se desplaza hacia arriba, y si b disminuye, se desplaza hacia abajo.

# %% [markdown]
# $$
# \textbf{Fórmula pendiente de una recta y punto de corte con el eje } x_2 \textbf{ a partir de la fórmula general de la recta}
# $$
#
#
# Partimos de la recta
#
# $$
# w_1 x_1 + w_2 x_2 + b = 0
# $$
#
# (suponiendo $w_2 \neq 0$).
#
# ---
#
# ### Forma explícita
#
# Despejando $x_2$:
#
# $$
# w_2 x_2 = -w_1 x_1 - b
# $$
#
# $$
# x_2 = -\frac{w_1}{w_2}x_1 - \frac{b}{w_2}
# $$
#
#
#
# ---
#
# ### Pendiente
#
# $$
# m = -\frac{w_1}{w_2}
# $$
#
# ---
#
# ### Punto de corte con el eje $x_2$
#
# El corte con el eje $x_2$ ocurre cuando $x_1 = 0$:
#
# $$
# x_2 = -\frac{b}{w_2}
# $$
#
# Por tanto, el punto de corte es:
#
# $$
# (0,\,-\frac{b}{w_2})
# $$
#
# ---
#
# ### Resumen
#
# $$
# x_2 = \underbrace{-\frac{w_1}{w_2}}_{\text{pendiente}}\,x_1 \;+\; \underbrace{\left(-\frac{b}{w_2}\right)}_{\text{corte en }x_2}
# $$
#
# **Caso especial:** si $w_2 = 0$, la recta es vertical y no se puede expresar como $x_2 = m x_1 + c$.

# %% [markdown]
# ### Ejemplo 5
#
# Ecuación general:
#
# $$
# -2x_1 - 5x_2 + 10 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = -2, \qquad w_2 = -5, \qquad b = 10
# $$
#
# Pendiente:
#
# $$
# m = -\frac{-2}{-5} = -\frac{2}{5}
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{10}{-5} = 2
# \quad \Rightarrow \quad (0,\,2)
# $$

# %% [markdown]
# $$
# \textbf{Ejemplos: identificación de: } w_2,   w_1, b \textbf{ y cálculo de } m \textbf{ e intersección con } x_2 \textbf{ a partir de la fórmula general de la recta }
# $$
#
# Partimos de la ecuación general de la recta:
#
# $$
# w_1 x_1 + w_2 x_2 + b = 0
# $$
#
# Si $w_2 \neq 0$, la pendiente y el punto de corte con el eje $x_2$ vienen dados por:
#
#
# $$
# m = -\frac{w_1}{w_2},
# \qquad
# x_2(0) = -\frac{b}{w_2}.
# $$
#
# ---
#
# ### Ejemplo 1
#
# Ecuación general:
#
# $$
# 2x_1 + x_2 - 4 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = 2, \qquad w_2 = 1, \qquad b = -4
# $$
#
# Pendiente:
#
# $$
# m = -\frac{2}{1} = -2
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{-4}{1} = 4
# \quad \Rightarrow \quad (0,\,4)
# $$

# %%
dibujar_recta(w1=2, w2=1, b=-4)

# %% [markdown]
# ### Ejemplo 2
#
# Ecuación general:
#
# $$
# -3x_1 + 2x_2 + 6 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = -3, \qquad w_2 = 2, \qquad b = 6
# $$
#
# Pendiente:
#
# $$
# m = -\frac{-3}{2} = \frac{3}{2}
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{6}{2} = -3
# \quad \Rightarrow \quad (0,\,-3)
# $$
#
# ---

# %%
dibujar_recta(w1=-3, w2=2, b=6)

# %% [markdown]
# ### Ejemplo 3
#
# Ecuación general:
#
# $$
# 5x_1 - 4x_2 + 8 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = 5, \qquad w_2 = -4, \qquad b = 8
# $$
#
# Pendiente:
#
# $$
# m = -\frac{5}{-4} = \frac{5}{4}
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{8}{-4} = 2
# \quad \Rightarrow \quad (0,\,2)
# $$

# %%
dibujar_recta(w1=5, w2=-4, b=8)

# %% [markdown]
# ### Ejemplo 4
#
# Ecuación general:
#
# $$
# x_1 + 3x_2 - 9 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = 1, \qquad w_2 = 3, \qquad b = -9
# $$
#
# Pendiente:
#
# $$
# m = -\frac{1}{3}
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{-9}{3} = 3
# \quad \Rightarrow \quad (0,\,3)
# $$

# %%
dibujar_recta(w1=1, w2=3, b=-9)

# %% [markdown]
# ### Ejemplo 5
#
# Ecuación general:
#
# $$
# -2x_1 - 5x_2 + 10 = 0
# $$
#
# Identificación de parámetros:
#
# $$
# w_1 = -2, \qquad w_2 = -5, \qquad b = 10
# $$
#
# Pendiente:
#
# $$
# m = -\frac{-2}{-5} = -\frac{2}{5}
# $$
#
# Intersección con el eje $x_2$:
#
#
# $$
# x_2(0) = -\frac{10}{-5} = 2
# \quad \Rightarrow \quad (0,\,2)
# $$

# %%
dibujar_recta(w1=-2, w2=-5, b=10)

# %%
# Efecto de b en la gráfica de la recta

def dibujar_rectas(w1, w2, rango_b):
    """
    Dibuja la recta w1*x1 + w2*x2 + b = 0
    """
    plt.figure(figsize=(8, 8))
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-10, 10, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    for b in rango_b:
        x2 = -(w1 * x1 + b) / w2
        # Dibujamos la recta usando matplotlib
        plt.plot(x1, x2, label=f'b = {b}')
        
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Rectas: ${w1}x_1 + {w2}x_2 + b = 0$'
    )
    plt.grid(True) 
    plt.legend()
    # Mostramos la figura en pantalla
    plt.show()

rango_b = [b for b in range (-12, 13, 3)]
rango_b
dibujar_rectas(w1 = 4, w2 = 1, rango_b = rango_b)

# %%
# Efecto de b en la gráfica de la recta de w1

def dibujar_rectas(rango_w1, w2, b):
    """
    Dibuja la recta w1*x1 + w2*x2 + b = 0
    """
    plt.figure(figsize=(8, 8))
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-10, 10, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    for w1 in rango_w1:
        x2 = -(w1 * x1 + b) / w2
        # Dibujamos la recta usando matplotlib
        plt.plot(x1, x2, label=f'w1 = {w1}')
        
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Rectas: $w_1x_1 + {w2}x_2 + {b} = 0$'
    )
    plt.grid(True) 
    plt.legend()
    # Mostramos la figura en pantalla
    plt.show()

rango_w1 = [w1 for w1 in range (-12, 13, 3)]

dibujar_rectas(rango_w1 = rango_w1, w2 = 1, b=10)

# %%
# Efecto de w2 en la gráfica de la recta 

def dibujar_rectas(w1, rango_w2, b):
    """
    Dibuja la recta w1*x1 + w2*x2 + b = 0
    """
    plt.figure(figsize=(8, 8))
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -20 y 10
    x1 = np.linspace(-20, 10, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    for w2 in rango_w2:
        x2 = -(w1 * x1 + b) / w2
        # Dibujamos la recta usando matplotlib
        plt.plot(x1, x2, label=f'w2 = {w2}')
        
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Rectas: ${w1}x_1 + w_2x_2 + {b} = 0$'
    )
    plt.grid(True) 
    plt.legend()
    # Mostramos la figura en pantalla
    plt.show()

rango_w2 = [w2 for w2 in range (1, 16, 3)]
print(rango_w2)
dibujar_rectas(w1 = 1, rango_w2 = rango_w2, b=10)
# Out:
# [1, 4, 7, 10, 13]

# %%
# Definimos la función 'agregacion' que nos permite evaluar la ecuación de la recta un punto (x1, x2)
# dados los pesos w1 y w2
w1=1
w2=1
b=-6.4
def agregacion(x1, x2, w1 = 1, w2 = 1, b = -6.4):
    return w1*x1 + w2*x2 + b
    
# Definimos la función 'activacion' que nos permite conocer a que grupo pertenece un punto 
# que se ha evaluado previamente con la función de 'agregacion'
def activacion(z):
    return 1 if z >= 0.0 else 0

# %%
#Ejercicio
#-------------------------------------------------------------------------------------------------
#Encontrar la recta (los valores w1, w2 -llamados pesos- y b) que separe los grupos de puntos dados
#--------------------------------------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

X = [
    [0.8, 0.8],
    [1.8, 1.0],
    [2.0, 2.5],
    [2.4, 1.5],
    [4.5, 3.5],
    [5.0, 4.2],
    [6.0, 4.5],
    [6.0, 2.0]
]

def encontrar_recta_separa_grupos(X, w1, w2, b):
    plt.figure(figsize=(8, 8))   
    
    x = [p[0] for p in X]
    y = [p[1] for p in X]    

    # Dibujamos cada grupo con distinto color y marcador
    plt.plot(x, y, 'o', label="Puntos", markersize=3) 


    # Dibuja la recta w1*x1 + w2*x2 + b = 0   
   
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-10, 10, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    x2 = -(w1 * x1 + b) / w2

    # Dibujamos la recta usando matplotlib
    plt.plot(x1, x2, color="red")

    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Recta: ${w1}x_1 + {w2}x_2 + ({b}) = 0$'
    )
    #plt.title(r"Gráfica recta $w_1 x_1 + w_2 x_2 + b = 0$")
    plt.grid(True)
   
    
    # Mostramos la figura en pantalla
    plt.xlim(-10, 10) # definimos rango del eje x
    plt.ylim(-10, 10) # definimos rango del eje y
    plt.show()

# valores inciales (aleatorios) de w1, w2 y b
import random

w1 = random.uniform(-2, 2)
w2 = random.uniform(-2, 2)
b  = random.uniform(-1, 1)

print("w1 =", w1, "w2 =", w2, "b =", b)

encontrar_recta_separa_grupos(X, w1, w2, b)

X = [
    [0.8, 0.8],
    [1.8, 1.0],
    [2.0, 2.5],
    [2.4, 1.5],
    [4.5, 3.5],
    [5.0, 4.2],
    [6.0, 4.5],
    [6.0, 2.0]
]

y = [0, 0, 0, 0, 1, 1, 1, 1]
# Out:
# w1 = -1.8808111222477186 w2 = -1.1254481007855865 b = 0.010710576206724776

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

# Descargar imagen
response = requests.get("https://drive.google.com/uc?export=download&id=18oUS6Ut90WqeE2YkY7oT9Ie3AHsCEWg_")

# Cargar y mostrar
img = Image.open(BytesIO(response.content))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def encontrar_recta_separa_grupos(X, w1, w2, b):
    plt.figure(figsize=(10, 10))

    x = [p[0] for p in X]
    y = [p[1] for p in X]  
   

    # Dibujamos cada grupo con distinto color y marcador
    plt.plot(x, y, 'o', markersize=3)

    # Dibuja la recta w1*x1 + w2*x2 + b = 0    
   
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-8, 8, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    x2 = -(w1/w2) * x1 - (b/w2)

    # Origen: corte con eje y
    x_origen = 0
    y_origen = -b / w2
    
    plt.plot(x1, x2, color="red")
    # dibujamos el vector w = (w1, w2) desde un punto de la recta (0, -b/w2)
    plt.quiver(x_origen, y_origen,                 # (0,-b/w2) origen del vector
               w1, w2,                   # componentes del vector. Indican su dirección y magnitud
               angles="xy",              # el vector se dibuja con su dirección real en el plano
               scale_units="xy",         # la escala del vector se mide en las mismas unidades de los ejes x e y
               scale=1,                  # longitud “normal”. Cuanto más pequeño es scale más grande es la flecha
               color='red'               # color de la flecha
              )
    plt.text(2, 2, " x", fontsize=12, color="black")
    
   # Origen: corte con eje y
    x_origen = 0
    y_origen = -b / w2

    # Vector azul hacia el punto (0.8, 0.8)
    px1, py1 = 1.8, 1
    plt.quiver(x_origen, y_origen,
           px1 - x_origen, py1 - y_origen,
           angles="xy",
           scale_units="xy",
           scale=1,
           color='blue')

    # Vector naranja hacia el punto (6, 4.5)
    px2, py2 = 4.5, 3.5
    plt.quiver(x_origen, y_origen,
           px2 - x_origen, py2 - y_origen,
           angles="xy",
           scale_units="xy",
           scale=1,
           color='orange')
    plt.text(w1, w2, " w", fontsize=12, color="red")
    
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Recta: ${w1}x_1 + {w2}x_2 + ({b}) = 0$'
    )
    #plt.title(r"Gráfica recta $w_1 x_1 + w_2 x_2 + b = 0$")
    plt.grid(True)

    plt.xlim(-8, 8) # definimos rango del eje x
    plt.ylim(-8, 8) # definimos rango del eje y
   
    #plt.legend() # mostramos la leyenda que identifica cada grupo
    # Etiquetas cerca de la punta de cada vector 
    # Mostramos la figura en pantalla
    plt.show()

# valores inciales (aleatorios) de w1, w2 y b
w1 = 1
w2 = -2
b = 0.45
encontrar_recta_separa_grupos(X,w1, w2, b)


# En este caso, con estos valores de w1, w2 y b, al punto (2,2) la recta lo asigna al grupo 1 -erróneamente- y no al cero)

# %% [markdown]
# # Perceptrón binario (clases 0/1) — 1 época con los datos de clase
#
# ## Parámetros iniciales
#
# Recta inicial (según la figura):
#
# $$
# 1x_1 + (-2)x_2 + (1)=0
# \Rightarrow w_1=1,\; w_2=-2,\; b=1
# $$
#
# Tasa de aprendizaje (**alfa**):
#
# $$
# \alpha = 0.1 \quad \text{(tasa de aprendizaje)}
# $$
#
#
#
# ## Estructura del perceptrón:
#
# ### 1) Agregación (**función de agregación**)
#
# $$
# z = w_1x_1 + w_2x_2 + b
# $$
#
# ### 2) Salida del perceptrón (**función de activación**)
#
# $$
# a =
# \begin{cases}
# 1 & \text{si } z \ge 0\\
# 0 & \text{si } z < 0
# \end{cases}
# $$
#
# ### 3) Error: es la diferencia entre la etiqueta del grupo asignado a un punto por el perceptrón (a) y la que tiene realmente (y).
# #### Si un punto pertenece al grupo 1 (y=1) y el perceptrón le asigna 0 (a=0), el error es e = y - a = 1 - 0 = 0.
# #### Si un punto pertenece al grupo 0 (y = 0) y el perceptrón le asigna 0 (a = 0), el error es e = y - a = 0 - 1 = -1.
#
# $$
# e = (y-a)
# $$
#
# ### 4) Actualización de los parámetros del Perceptrón: w1, w2 y b. De esta manera, el Perceptrón encuentra ('aprende') los parámetros óptimos que le permitan dividir correctamente los grupos de puntos sus clases correspondientes, de forma automática. No necesitamos encontrar estos parámetros de forma manual.
#
# $$
# \Large
# w_1 \leftarrow w_1 + \alpha\, e\, x_1
# $$
#
# $$
# \Large
# w_2 \leftarrow w_2 + \alpha\, e\, x_2
# $$
#
# $$
# \Large
# b \leftarrow b + \alpha\, e
# $$
#
#
#
# ## Datos de cada grupo. Queremos encontrar, de forma automática, una recta que separe estos grupos de puntos.
#
# ### Grupo 0 (etiqueta $y=0$)
# 1. $x=(0.8,\;0.8)$
# 2. $x=(1.8,\;1.0)$
# 3. $x=(2.0,\;2.0)$
# 4. $x=(2.4,\;1.5)$
#
# ### Grupo 1 (etiqueta $y=1$)
# 5. $x=(4.5,\;3.5)$
# 6. $x=(5.0,\;4.2)$
# 7. $x=(6.0,\;4.5)$
# 8. $x=(6.0,\;2.0)$
#
#
#
# $w_1 = 1$
#
# $w_2 = -2$
#
# $b = 1$
#
# # Época 1 (cálculos paso a paso) con $\alpha=0.1$
#
# ## Punto 1: $x=(0.8,0.8),\; y=0$
#
# **Agregación:**
#
# $$
# z = 1(0.8) + (-2)(0.8) + 1 = 0.8 - 1.6 + 1 = 0.2
# $$
#
# **Activación:**
#
# $$
# z=0.2\ge 0 \Rightarrow a=1
# $$
#
# **Error:**
#
# $$
# e = y-a = 0-1 = -1
# $$
#
# **Actualización:**
#
# $$
# w_1 \leftarrow 1 + 0.1(-1)(0.8) = 1 - 0.08 = 0.92
# $$
#
# $$
# w_2 \leftarrow -2 + 0.1(-1)(0.8) = -2 - 0.08 = -2.08
# $$
#
# $$
# b \leftarrow 1 + 0.1(-1) = 1 - 0.1 = 0.9
# $$
#
# **Estado tras el punto 1:**
#
# $$
# w_1=0.92,\; w_2=-2.08,\; b=0.9
# $$
#
#
#
# ## Punto 2: $x=(1.8,1.0),\; y=0$
#
# **Agregación:**
#
# $$
# z = 0.92(1.8) + (-2.08)(1.0) + 0.9
# $$
#
# $$
# z = 1.656 - 2.08 + 0.9 = 0.476
# $$
#
# **Activación:**
#
# $$
# z=0.476\ge 0 \Rightarrow a=1
# $$
#
# **Error:**
#
# $$
# e = 0-1 = -1
# $$
#
# **Actualización:**
#
# $$
# w_1 \leftarrow 0.92 + 0.1(-1)(1.8) = 0.92 - 0.18 = 0.74
# $$
#
# $$
# w_2 \leftarrow -2.08 + 0.1(-1)(1.0) = -2.08 - 0.1 = -2.18
# $$
#
# $$
# b \leftarrow 0.9 + 0.1(-1) = 0.8
# $$
#
# **Estado tras el punto 2:**
#
# $$
# w_1=0.74,\; w_2=-2.18,\; b=0.8
# $$
#
#
#
# ## Punto 3: $x=(2.0,2.0),\; y=0$
#
# **Agregación:**
#
# $$
# z = 0.74(2.0) + (-2.18)(2.0) + 0.8
# $$
#
# $$
# z = 1.48 - 4.36 + 0.8 = -2.08
# $$
#
# **Activación y error:**
#
# $$
# z<0 \Rightarrow a=0,\qquad e=0-0=0
# $$
#
# Sin cambios.
#
#
#
# ## Punto 4: $x=(2.4,1.5),\; y=0$
#
# **Agregación:**
#
# $$
# z = 0.74(2.4) + (-2.18)(1.5) + 0.8
# $$
#
# $$
# z = 1.776 - 3.27 + 0.8 = -0.694
# $$
#
# **Activación y error:**
#
# $$
# z<0 \Rightarrow a=0,\qquad e=0
# $$
#
# Sin cambios.
#
#
#
# ## Punto 5: $x=(4.5,3.5),\; y=1$
#
# **Agregación:**
#
# $$
# z = 0.74(4.5) + (-2.18)(3.5) + 0.8
# $$
#
# $$
# z = 3.33 - 7.63 + 0.8 = -3.5
# $$
#
# **Activación:**
#
# $$
# z<0 \Rightarrow a=0
# $$
#
# **Error:**
#
# $$
# e = 1-0 = 1
# $$
#
# **Actualización:**
#
# $$
# w_1 \leftarrow 0.74 + 0.1(1)(4.5) = 0.74 + 0.45 = 1.19
# $$
#
# $$
# w_2 \leftarrow -2.18 + 0.1(1)(3.5) = -2.18 + 0.35 = -1.83
# $$
#
# $$
# b \leftarrow 0.8 + 0.1(1) = 0.9
# $$
#
# **Estado tras el punto 5:**
#
# $$
# w_1=1.19,\; w_2=-1.83,\; b=0.9
# $$
#
#
#
# ## Punto 6: $x=(5.0,4.2),\; y=1$
#
# **Agregación:**
#
# $$
# z = 1.19(5.0) + (-1.83)(4.2) + 0.9
# $$
#
# $$
# z = 5.95 - 7.686 + 0.9 = -0.836
# $$
#
# **Activación y error:**
#
# $$
# z<0 \Rightarrow a=0,\qquad e=1-0=1
# $$
#
# **Actualización:**
#
# $$
# w_1 \leftarrow 1.19 + 0.1(1)(5.0) = 1.19 + 0.5 = 1.69
# $$
#
# $$
# w_2 \leftarrow -1.83 + 0.1(1)(4.2) = -1.83 + 0.42 = -1.41
# $$
#
# $$
# b \leftarrow 0.9 + 0.1(1) = 1.0
# $$
#
# **Estado tras el punto 6:**
#
# $$
# w_1=1.69,\; w_2=-1.41,\; b=1.0
# $$
#
#
#
# ## Punto 7: $x=(6.0,4.5),\; y=1$
#
# $$
# z = 1.69(6.0) + (-1.41)(4.5) + 1.0
# = 10.14 - 6.345 + 1.0 = 4.795
# $$
#
# $$
# z\ge 0 \Rightarrow a=1,\qquad e=1-1=0
# $$
#
# Sin cambios.
#
#
#
# ## Punto 8: $x=(6.0,2.0),\; y=1$
#
# $$
# z = 1.69(6.0) + (-1.41)(2.0) + 1.0
# = 10.14 - 2.82 + 1.0 = 8.32
# $$
#
# $$
# z\ge 0 \Rightarrow a=1,\qquad e=0
# $$
#
# Sin cambios.
#
#
#
# # Resultado final tras 1 época (α = 0.1)
#
# Se han producido **4 actualizaciones** (puntos 1, 2, 5 y 6).
#
# $$
# \boxed{w_1=1.69,\quad w_2=-1.41,\quad b=1.0}
# $$

# %%
# Recta con los pesos actualizados
w1 = 1.69
w2 = -1.41
b = 1

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %%
import numpy as np

# Funcion escalon binaria (0/1)
def activacion(z):
    # Si z >= 0 -> 1, si z < 0 -> 0
    return 1 if z >= 0 else 0

# Calcula z = w1*x1 + w2*x2 + b (formula explicita)
def agregacion(w1, w2, b, x1, x2):
    # z = w1*x1 + w2*x2 + b
    return w1*x1 + w2*x2 + b

# Ejecuta 1 epoca completa e imprime todas las operaciones
def perceptron_una_epoca(X, y, w1, w2, b, alfa=0.1):
    # Contador de actualizaciones (errores)
    actualizaciones = 0

    print("EJEMPLO DE APRENDIZAJE (1 EPOCA)")
    
    print("----------------------------------------")
    print(f"Inicial: w1={w1}, w2={w2}, b={b}, alfa={alfa}")

    # Recorremos los puntos en el orden dado
    for i in range(len(X)):
        x1, x2 = X[i]
        yi = y[i]

        # 1) Calculo de z
        z = agregacion(w1, w2, b, x1, x2)

        # 2) Prediccion a
        a = activacion(z)

        # 3) Error e
        e = yi - a

        # Mostrar calculos paso a paso
        print("\n----------------------------------------")
        print(f"Punto {i+1}: x=({x1}, {x2}), y={yi}")
        print(f"  z = w1*x1 + w2*x2 + b")
        print(f"    = ({w1})*({x1}) + ({w2})*({x2}) + ({b})")
        print(f"    = {z:.4f}")
        print(f"  a = activacion(z) = {a}  (porque z {'>=' if z>=0 else '<'} 0)")
        print(f"  e = (y - a) = {yi} - {a} = {e}")

        # 4) Actualizacion si hay error
        if e != 0:
            w1 = w1 + alfa*e*x1
            w2 = w2 + alfa*e*x2
            b  = b  + alfa*e

            print("  ACTUALIZACION (porque error e es diferente 0):")
            print(f"    w1 <- w1 + eta*e*x1 = {w1} + {alfa}*({e})*({x1})")
            print(f"    w2 <- w2 + eta*e*x2 = {w2} + {alfa}*({e})*({x2})")
            print(f"    b  <- b  + eta*e     = {b} + {alfa}*({e}")

            actualizaciones += 1
        else:
            print("  Sin actualizacion (e = 0).")

        print(f"  Estado tras el punto {i+1}: w1={w1}, w2={w2}, b={b}")

    print("\n========================================")
    print(f"Fin de la epoca: actualizaciones (errores) = {actualizaciones}")
    print(f"Parametros finales: w1={w1}, w2={w2}, b={b}")
    return w1, w2, b

# ------------------------------
# DATOS DE CLASE
# ------------------------------
X = [
    [0.8, 0.8],
    [1.8, 1.0],
    [2.0, 2.5],
    [2.4, 1.5],
    [4.5, 3.5],
    [5.0, 4.2],
    [6.0, 4.5],
    [6.0, 2.0]
]

y = [0, 0, 0, 0, 1, 1, 1, 1]

# Parametros iniciales (los de tu figura)
w1 = 0.5
w2 = -0.3
b  = 1

# Ejecutamos 1 epoca (eta=0.1 para cuentas faciles)
w1, w2, b = perceptron_una_epoca(X, y, w1, w2 ,  b , alfa=0.1)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.5, w2=-0.3, b=1, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5)*(0.8) + (-0.3)*(0.8) + (1)
#     = 1.1600
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.42 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.38 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 0.9 + 0.1*(-1
#   Estado tras el punto 1: w1=0.42, w2=-0.38, b=0.9
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.42)*(1.8) + (-0.38)*(1.0) + (0.9)
#     = 1.2760
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.23999999999999996 + 0.1*(-1)*(1.8)
#     w2 <- w2 + eta*e*x2 = -0.48 + 0.1*(-1)*(1.0)
# ...

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.49, w2=-0.37999999999999995, b=0.8, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.49)*(0.8) + (-0.37999999999999995)*(0.8) + (0.8)
#     = 0.8880
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.41 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.45999999999999996 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 0.7000000000000001 + 0.1*(-1
#   Estado tras el punto 1: w1=0.41, w2=-0.45999999999999996, b=0.7000000000000001
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.41)*(1.8) + (-0.45999999999999996)*(1.0) + (0.7000000000000001)
#     = 0.9780
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
# ...

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %%
w1,w2,b=perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.43999999999999995, w2=-0.35999999999999993, b=0.6000000000000001, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.43999999999999995)*(0.8) + (-0.35999999999999993)*(0.8) + (0.6000000000000001)
#     = 0.6640
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.35999999999999993 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.43999999999999995 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 0.5000000000000001 + 0.1*(-1
#   Estado tras el punto 1: w1=0.35999999999999993, w2=-0.43999999999999995, b=0.5000000000000001
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.35999999999999993)*(1.8) + (-0.43999999999999995)*(1.0) + (0.5000000000000001)
#     = 0.7080
# ...

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %%
w1,w2,b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.3899999999999999, w2=-0.3399999999999999, b=0.40000000000000013, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.3899999999999999)*(0.8) + (-0.3399999999999999)*(0.8) + (0.40000000000000013)
#     = 0.4400
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.3099999999999999 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.41999999999999993 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 0.30000000000000016 + 0.1*(-1
#   Estado tras el punto 1: w1=0.3099999999999999, w2=-0.41999999999999993, b=0.30000000000000016
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.3099999999999999)*(1.8) + (-0.41999999999999993)*(1.0) + (0.30000000000000016)
#     = 0.4380
# ...

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.5799999999999998, w2=-0.16999999999999987, b=0.30000000000000016, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5799999999999998)*(0.8) + (-0.16999999999999987)*(0.8) + (0.30000000000000016)
#     = 0.6280
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.49999999999999983 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.2499999999999999 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 0.20000000000000015 + 0.1*(-1
#   Estado tras el punto 1: w1=0.49999999999999983, w2=-0.2499999999999999, b=0.20000000000000015
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.49999999999999983)*(1.8) + (-0.2499999999999999)*(1.0) + (0.20000000000000015)
#     = 0.8500
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.5299999999999998, w2=-0.14999999999999986, b=0.10000000000000014, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5299999999999998)*(0.8) + (-0.14999999999999986)*(0.8) + (0.10000000000000014)
#     = 0.4040
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.4499999999999998 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.22999999999999987 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = 1.3877787807814457e-16 + 0.1*(-1
#   Estado tras el punto 1: w1=0.4499999999999998, w2=-0.22999999999999987, b=1.3877787807814457e-16
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.4499999999999998)*(1.8) + (-0.22999999999999987)*(1.0) + (1.3877787807814457e-16)
#     = 0.5800
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.4799999999999998, w2=-0.12999999999999984, b=-0.09999999999999987, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.4799999999999998)*(0.8) + (-0.12999999999999984)*(0.8) + (-0.09999999999999987)
#     = 0.1800
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.3999999999999998 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.20999999999999985 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = -0.19999999999999987 + 0.1*(-1
#   Estado tras el punto 1: w1=0.3999999999999998, w2=-0.20999999999999985, b=-0.19999999999999987
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.3999999999999998)*(1.8) + (-0.20999999999999985)*(1.0) + (-0.19999999999999987)
#     = 0.3100
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.6699999999999998, w2=0.0400000000000002, b=-0.19999999999999987, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6699999999999998)*(0.8) + (0.0400000000000002)*(0.8) + (-0.19999999999999987)
#     = 0.3680
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.5899999999999999 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.039999999999999813 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = -0.2999999999999999 + 0.1*(-1
#   Estado tras el punto 1: w1=0.5899999999999999, w2=-0.039999999999999813, b=-0.2999999999999999
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5899999999999999)*(1.8) + (-0.039999999999999813)*(1.0) + (-0.2999999999999999)
#     = 0.7220
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.6599999999999998, w2=-0.03999999999999976, b=-0.3999999999999999, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6599999999999998)*(0.8) + (-0.03999999999999976)*(0.8) + (-0.3999999999999999)
#     = 0.0960
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.5799999999999998 + 0.1*(-1)*(0.8)
#     w2 <- w2 + eta*e*x2 = -0.11999999999999977 + 0.1*(-1)*(0.8)
#     b  <- b  + eta*e     = -0.4999999999999999 + 0.1*(-1
#   Estado tras el punto 1: w1=0.5799999999999998, w2=-0.11999999999999977, b=-0.4999999999999999
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5799999999999998)*(1.8) + (-0.11999999999999977)*(1.0) + (-0.4999999999999999)
#     = 0.4240
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.6099999999999999, w2=-0.01999999999999974, b=-0.5999999999999999, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6099999999999999)*(0.8) + (-0.01999999999999974)*(0.8) + (-0.5999999999999999)
#     = -0.1280
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.6099999999999999, w2=-0.01999999999999974, b=-0.5999999999999999
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6099999999999999)*(1.8) + (-0.01999999999999974)*(1.0) + (-0.5999999999999999)
#     = 0.4780
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.4299999999999998 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.6399999999999999, w2=0.08000000000000024, b=-0.6999999999999998, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6399999999999999)*(0.8) + (0.08000000000000024)*(0.8) + (-0.6999999999999998)
#     = -0.1240
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.6399999999999999, w2=0.08000000000000024, b=-0.6999999999999998
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.6399999999999999)*(1.8) + (0.08000000000000024)*(1.0) + (-0.6999999999999998)
#     = 0.5320
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.45999999999999985 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.7099999999999999, w2=0.08000000000000024, b=-0.7999999999999998, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.7099999999999999)*(0.8) + (0.08000000000000024)*(0.8) + (-0.7999999999999998)
#     = -0.1680
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.7099999999999999, w2=0.08000000000000024, b=-0.7999999999999998
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.7099999999999999)*(1.8) + (0.08000000000000024)*(1.0) + (-0.7999999999999998)
#     = 0.5580
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.5299999999999998 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.7799999999999998, w2=0.08000000000000024, b=-0.8999999999999998, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.7799999999999998)*(0.8) + (0.08000000000000024)*(0.8) + (-0.8999999999999998)
#     = -0.2120
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.7799999999999998, w2=0.08000000000000024, b=-0.8999999999999998
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.7799999999999998)*(1.8) + (0.08000000000000024)*(1.0) + (-0.8999999999999998)
#     = 0.5840
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.5999999999999998 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.8499999999999998, w2=0.08000000000000024, b=-0.9999999999999999, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.8499999999999998)*(0.8) + (0.08000000000000024)*(0.8) + (-0.9999999999999999)
#     = -0.2560
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.8499999999999998, w2=0.08000000000000024, b=-0.9999999999999999
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.8499999999999998)*(1.8) + (0.08000000000000024)*(1.0) + (-0.9999999999999999)
#     = 0.6100
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.6699999999999997 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.9199999999999997, w2=0.08000000000000024, b=-1.0999999999999999, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.9199999999999997)*(0.8) + (0.08000000000000024)*(0.8) + (-1.0999999999999999)
#     = -0.3000
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.9199999999999997, w2=0.08000000000000024, b=-1.0999999999999999
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.9199999999999997)*(1.8) + (0.08000000000000024)*(1.0) + (-1.0999999999999999)
#     = 0.6360
#   a = activacion(z) = 1  (porque z >= 0)
#   e = (y - a) = 0 - 1 = -1
#   ACTUALIZACION (porque error e es diferente 0):
#     w1 <- w1 + eta*e*x1 = 0.7399999999999997 + 0.1*(-1)*(1.8)
# ...

# %%
w1, w2, b = perceptron_una_epoca(X, y, w1, w2, b)
# Out:
# EJEMPLO DE APRENDIZAJE (1 EPOCA)
# ----------------------------------------
# Inicial: w1=0.5399999999999996, w2=-0.2699999999999998, b=-1.3, alfa=0.1
#
# ----------------------------------------
# Punto 1: x=(0.8, 0.8), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5399999999999996)*(0.8) + (-0.2699999999999998)*(0.8) + (-1.3)
#     = -1.0840
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 1: w1=0.5399999999999996, w2=-0.2699999999999998, b=-1.3
#
# ----------------------------------------
# Punto 2: x=(1.8, 1.0), y=0
#   z = w1*x1 + w2*x2 + b
#     = (0.5399999999999996)*(1.8) + (-0.2699999999999998)*(1.0) + (-1.3)
#     = -0.5980
#   a = activacion(z) = 0  (porque z < 0)
#   e = (y - a) = 0 - 0 = 0
#   Sin actualizacion (e = 0).
#   Estado tras el punto 2: w1=0.5399999999999996, w2=-0.2699999999999998, b=-1.3
#
# ----------------------------------------
# Punto 3: x=(2.0, 2.5), y=0
#   z = w1*x1 + w2*x2 + b
# ...

# %%
encontrar_recta_separa_grupos(X, w1, w2, b)

# %% [markdown]
# # Perceptrón simple — Pseudocódigo
#
# El objetivo del **perceptrón simple** es la clasificación binaria (clases 0 y 1) mediante la construcción de una línea recta que separa dos grupos de puntos.
#
#
#
# ## 1. Variables principales
#
# - $X$: conjunto de entrenamiento. Cada ejemplo es un vector: $(x_1, x_2)$
#
# - $y$: etiquetas reales del conjunto (lista). Cada etiqueta es $0$ o $1$
#
# - $(w_1, w_2)$: vector de pesos
#
# - $b$: sesgo (*bias*)
#
# - $\alpha\$: tasa de aprendizaje (`learning_rate`)
#
# - `epocas`: número de veces que se recorre el conjunto de entrenamiento
#
# ## 2. Idea matemática del perceptrón
#
# Para un ejemplo $(x_1, x_2)$, se calcula:
#
# $$
# \Large
# z = w_1x_1 + w_2x_2 + b
# $$
#
# La salida predicha $\hat{y}$ se obtiene con una función escalón:
#
# $$
# \Large
# \hat{y} = a(z) =
# \begin{cases}
# 1 & \text{si } z \ge 0 \\
# 0 & \text{si } z < 0
# \end{cases}
# $$
#
# Se calcula el error:
#
# $$
# \Large
# \text{error} = y - \hat{y}
# $$
#
# Y se actualizan los parámetros:
#
# $$
# \Large
# w_1 \leftarrow w_1 + \alpha\, error\, x_1
# $$
#
# $$
# \Large
# w_2 \leftarrow w_2 + \alpha\, error\, x_2
# $$
#
# $$
# \Large
# b \leftarrow b + \alpha\, error
# $$

# %%
X = [

# ----- CLASE 0 (50 puntos, nube redonda cerca de la frontera: x2 <= x1 + 0.18) -----
[1.40,1.52],[1.44,1.55],[1.48,1.58],[1.52,1.62],[1.56,1.66],
[1.60,1.70],[1.64,1.74],[1.68,1.78],[1.72,1.82],[1.76,1.86],
[1.42,1.56],[1.46,1.59],[1.50,1.61],[1.54,1.65],[1.58,1.69],
[1.62,1.73],[1.66,1.76],[1.70,1.80],[1.74,1.84],[1.78,1.88],
[1.41,1.54],[1.45,1.57],[1.49,1.60],[1.53,1.64],[1.57,1.67],
[1.61,1.71],[1.65,1.75],[1.69,1.79],[1.73,1.83],[1.77,1.87],
[1.43,1.58],[1.47,1.62],[1.51,1.66],[1.55,1.69],[1.59,1.73],
[1.63,1.77],[1.67,1.80],[1.71,1.84],[1.75,1.88],[1.79,1.92],
[1.44,1.60],[1.50,1.65],[1.56,1.70],[1.62,1.76],[1.68,1.81],
[1.74,1.86],[1.46,1.61],[1.58,1.72],[1.70,1.82],[1.78,1.89],

# ----- CLASE 1 (50 puntos, x2 >= x1 + 0.22) -----
[1.62,1.88],[1.66,1.92],[1.70,1.96],[1.74,2.00],[1.78,2.04],
[1.82,2.08],[1.86,2.12],[1.90,2.16],[1.94,2.20],[1.98,2.24],
[1.64,1.90],[1.68,1.94],[1.72,1.99],[1.76,2.03],[1.80,2.07],
[1.84,2.11],[1.88,2.15],[1.92,2.19],[1.96,2.23],[2.00,2.27],
[1.63,1.91],[1.67,1.95],[1.71,2.01],[1.75,2.04],[1.79,2.10],
[1.83,2.13],[1.87,2.17],[1.91,2.22],[1.95,2.25],[1.99,2.29],
[1.65,1.93],[1.69,1.98],[1.73,2.02],[1.77,2.07],[1.81,2.11],
[1.85,2.16],[1.89,2.18],[1.93,2.23],[1.97,2.26],[2.01,2.30],
[1.66,1.94],[1.72,2.00],[1.78,2.06],[1.84,2.12],[1.90,2.18],
[1.96,2.24],[1.68,1.97],[1.80,2.09],[1.92,2.21],[2.00,2.28]
]

y = [0]*50 + [1]*50

# %%
# Importamos las librerías necesarias
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Dividir en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    X,                # Matriz de características de entrada (features)-atributos de entrada-variables predictoras
    y,                # Vector/serie con la variable objetivo (labels-eneste caso: class)
    test_size=0.2,    # Proporción para el conjunto de prueba y bel conjunto de entrenamiento: 20% test, 80% train
    random_state=42,  # Semilla para que la división sea reproducible
    shuffle=True,     # Barajar aleatoriamente antes de dividir (recomendado si no hay una serie temporal)
    stratify=y        # mantiene proporciones de clases
)
X_train
# Out:
# [[1.62, 1.73],
#  [1.7, 1.96],
#  [1.64, 1.9],
#  [1.88, 2.15],
#  [1.96, 2.23],
#  [1.64, 1.74],
#  [1.47, 1.62],
#  [1.98, 2.24],
#  [1.46, 1.61],
#  [2.0, 2.28],
#  [1.59, 1.73],
#  [1.63, 1.77],
#  [1.89, 2.18],
#  [1.95, 2.25],
#  [2.01, 2.3],
#  [1.5, 1.65],
#  [1.65, 1.93],
#  [1.48, 1.58],
#  [1.5, 1.61],
#  [1.79, 2.1],
#  [1.68, 1.94],
#  [1.7, 1.82],
#  [1.76, 1.86],
#  [1.77, 1.87],
#  [1.78, 1.88],
#  [1.79, 1.92],
#  [1.63, 1.91],
#  [1.58, 1.72],
#  [1.67, 1.95],
#  [1.92, 2.19],
#  [1.93, 2.23],
#  [1.78, 2.04],
#  [1.55, 1.69],
#  [1.87, 2.17],
#  [1.66, 1.94],
#  [1.6, 1.7],
#  [1.74, 1.86],
#  [1.84, 2.11],
#  [1.72, 2.0],
#  [1.46, 1.59],
#  [1.71, 1.84],
#  [1.97, 2.26],
#  [1.62, 1.88],
#  [1.96, 2.24],
#  [1.52, 1.62],
#  [1.51, 1.66],
#  [1.69, 1.98],
#  [1.53, 1.64],
#  [1.77, 2.07],
#  [1.4, 1.52],
#  [1.82, 2.08],
#  [1.73, 2.02],
#  [1.43, 1.58],
#  [1.72, 1.82],
#  [1.71, 2.01],
#  [1.8, 2.07],
#  [1.72, 1.99],
#  [1.54, 1.65],
#  [1.78, 2.06],
# ...

# %%
import matplotlib.pyplot as plt

# separar columnas
x1 = [p[0] for p in X]
x2 = [p[1] for p in X]

plt.figure(figsize=(6,6))
plt.scatter(x1, x2)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Representación de los datos")
plt.grid(True)

plt.show()

# %%
#-----------------------------------------------------#
# Versión simplificada del algoritmo del Perceptrón   #
#-----------------------------------------------------#


import random  # Para generar números aleatorios (pesos y bias iniciales)
import numpy as np

def activacion(z):
    # Función escalón: convierte un valor real z en una clase (0 o 1)
    # Si z >= 0 => clase 1; si z < 0 => clase 0
    if z >= 0:
        return 1
    else:
        return 0

def calcular_z(x1, x2, w1, w2, b):    
    # Calcula el valor lineal del perceptrón antes de activar:    
    return   w1 * x1 + w2 * x2 + b # Devolvemos el valor de z

def predecir(x1, x2, w1, w2, b):
    # Predice la clase (0 o 1) para un punto x
    z = calcular_z(x1, x2, w1, w2, b)  # Calculamos el valor lineal
    y_pred = activacion(z)             # Aplicamos activación para obtener 0 o 1
    return y_pred                      # Devolvemos la clase predicha

def entrenar_perceptron(X, y, epocas=100, learning_rate=0.1):
    # Entrena el perceptrón con:
    # X: lista de ejemplos (puntos) (cada ejemplo es una lista de características)
    # y: lista de etiquetas reales (0 o 1)
    # epocas: máximo de pasadas por el dataset
    # learning_rate: tamaño del paso de actualización (alpha)   

   
    m = len(X) # Número de puntos en la tabla (filas de X)
    n = len(X[0]) # Número de características, en este caso x1 y x2 son dos características por cada línea de X

    print("Filas:", m)
    print("Columnas:", n)

    
    # Inicialización aleatoria de w y b (valores pequeños).  Pesos iniciales    
    w1 = random.uniform(-0.5, 0.5)
    w2 = random.uniform(-0.5, 0.5)
    b = random.uniform(-0.5, 0.5)
    
    print("Pesos iniciales w:", w1, w2)
    print("Bias inicial b:", b)
    print("-" * 50)
    
    # Entrenamiento por épocas
    # ------------------------------------------------------------
    for epoca in range(epocas):
        errores_en_epoca = 0  # Contador de ejemplos mal clasificados en esta época

        # Recorremos los ejemplos (puntos-líneas de la tabla)
        for k in range(m):
            x1 = X[k][0]    # primer valor de la fila k de la columna 0 (la columna de los x1)
            x2 = X[k][1]    # segundo valor de la fila k de la columna 0 (la columna de los x1)
            y_real = y[k]   # Etiqueta real del ejemplo k
            
            y_pred = predecir(x1, x2, w1, w2, b) # Predicción actual (en esta época)
            
            error = y_real - y_pred              # Error (y real - y predicha)

            # Contamos si hubo error
            if error != 0:
                errores_en_epoca = errores_en_epoca + 1

            # Actualización de pesos
            w1 = w1 + learning_rate * error * x1 # Actualización de peso w1
            w2 = w2 + learning_rate * error * x2 # Actualización de peso w2 
            b = b + learning_rate * error        # Actualización del bias b

        # Resumen por época
        print(f"Época {epoca:03d} | Errores: {errores_en_epoca}")
        
        # Criterio de parada        
        if errores_en_epoca == 0:
            print(f"Algoritmo de aprendizaje terminado por 0 errores en la época {epoca}.")
            return w1, w2, b  # devolvemos los valores en la época en la que los errores llegan a ser cero
        
    print(f'Devolvemos los valores w1, w2 y b después de {epocas} épocas')
    return w1, w2, b  # Devolvemos los parámetros aprendidos de w1, w2 y b
#

# %%
# Entrenamos el perceptrón
w1, w2, b = entrenar_perceptron(X_train, y_train, epocas=100, learning_rate=0.1)

print("-" * 50)
print(f'w1 = {w1}  w2 = {w2}  b = {b}') # valores finales de w1, w2, y b
print("-" * 50)
# Out:
# Filas: 80
# Columnas: 2
# Pesos iniciales w: -0.4734640303161364 -0.3011623493133515
# Bias inicial b: 0.1498844377795232
# --------------------------------------------------
# Época 000 | Errores: 47
# Época 001 | Errores: 21
# Época 002 | Errores: 0
# Algoritmo de aprendizaje terminado por 0 errores en la época 2.
# --------------------------------------------------
# w1 = -0.2654640303161362  w2 = 0.3748376506866481  b = -0.2501155622204768
# --------------------------------------------------

# %%
# Probamos predicciones finales (en el conjunto de test) y mostramos z
# Probamos predicciones finales para los puntos (x1, x2) del conjunto de test
y_pred = []
for x1, x2 in X_test:
    y_pred.append(predecir(x1, x2, w1, w2, b))
    print(f'({x1},{x2}) | predicción={predecir(x1, x2, w1, w2, b)}')
y_pred
# Out:
# (1.9,2.16) | predicción=1
# (1.91,2.22) | predicción=1
# (1.76,2.03) | predicción=1
# (1.66,1.92) | predicción=1
# (1.68,1.78) | predicción=0
# (1.58,1.69) | predicción=0
# (1.41,1.54) | predicción=0
# (1.83,2.13) | predicción=1
# (1.74,1.84) | predicción=0
# (1.49,1.6) | predicción=0
# (1.56,1.7) | predicción=0
# (1.94,2.2) | predicción=1
# (1.78,1.89) | predicción=0
# (1.75,1.88) | predicción=0
# (1.42,1.56) | predicción=0
# (1.84,2.12) | predicción=1
# (2.0,2.27) | predicción=1
# (1.73,1.83) | predicción=0
# (1.86,2.12) | predicción=1
# (1.81,2.11) | predicción=1
# [1, 1, 1, 1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1, 1, 0, 1, 1]

# %%
# Matriz de confusión con conteos (para KNN)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt

labels = sorted(set(y_train))   # clases del problema
# Matriz de confusión (solo conteos)
mc = confusion_matrix(y_test, y_pred, labels=labels)

# Crear lienzo para dibujar la matriz de confusión
fig, axes = plt.subplots(figsize=(8, 8))  # aumenta el tamaño: ancho x alto


# Visualización Matriz de Confusión. 

labels = sorted(set(y_train))   # clases del problema
disp = ConfusionMatrixDisplay(                            # disp es un objeto de tipo ConfusionMatrixDisplay
                             confusion_matrix=mc,         # Matriz de confusión calculada previamente (con confusion_matrix())
                             display_labels=labels  # Etiquetas de las clases que el modelo KNN reconoce (por ejemplo, [0, 1])
                             )
disp.plot(
         cmap="Blues",                                    # Define el mapa de colores usado para pintar las celdas de la matriz.
         ax=axes,                                         # Especifica en qué figura o subgráfico se debe dibujar la matriz.
         colorbar=False                                   # Indica si se muestra o no la barra lateral de color (que representa la escala de valores).
         )

# Personalizar título y aspecto
axes.set_title("Matriz de Confusión (KNN)", fontsize=14)
axes.set_xlabel("Clase predicha", fontsize=12)
axes.set_ylabel("Clase real", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretación de la Matriz de Confusión
#
# | Tipo                     | Significado                                                        | Valor |
# | ------------------------ | ------------------------------------------------------------------ | ----- |
# | TP (True Positives)  | Casos __ correctamente clasificados como __                            |       |
# | TN (True Negatives)  | Casos __ correctamente clasificados como __                            |       |
# | FP (False Positives) | Casos __ clasificados erróneamente como  __                            |       |
# | FN (False Negatives) | Casos __ clasificados erróneamente como  __                            |       |

# %%
# Actividad 1
# Modifica el algoritmo de aprendizaje del Perceptrón. Utiliza un bucle while en lugar de un ciclo for para iterar sobre diferentes épocas.
def entrenar_perceptron(X, y, epocas=100, learning_rate=0.1):
    # Entrena el perceptrón con:
    # X: lista de ejemplos (puntos) (cada ejemplo es una lista de características)
    # y: lista de etiquetas reales (0 o 1)
    # epocas: máximo de pasadas por el dataset
    # learning_rate: tamaño del paso de actualización (alpha)   

   
    m = len(X) # Número de puntos en la tabla (filas de X)
    n = len(X[0]) # Número de características, en este caso x1 y x2 son dos características por cada línea de X

    print("Filas:", m)
    print("Columnas:", n)

    
    # Inicialización aleatoria de w y b (valores pequeños).  Pesos iniciales    
    w1 = random.uniform(-0.5, 0.5)
    w2 = random.uniform(-0.5, 0.5)
    b = random.uniform(-0.5, 0.5)
    
    print("Pesos iniciales w:", w1, w2)
    print("Bias inicial b:", b)
    print("-" * 50)
    
    # Entrenamiento por épocas
    # ------------------------------------------------------------
    epoca = 0
    while epoca < epocas:
        errores_en_epoca = 0  # Contador de ejemplos mal clasificados en esta época

        # Recorremos los ejemplos (puntos-líneas de la tabla)
        for k in range(m):
            x1 = X[k][0]    # primer valor de la fila k de la columna 0 (la columna de los x1)
            x2 = X[k][1]    # segundo valor de la fila k de la columna 0 (la columna de los x1)
            y_real = y[k]   # Etiqueta real del ejemplo k
            
            y_pred = predecir(x1, x2, w1, w2, b) # Predicción actual (en esta época)
            
            error = y_real - y_pred              # Error (y real - y predicha)

            # Contamos si hubo error
            if error != 0:
                errores_en_epoca = errores_en_epoca + 1

            # Actualización de pesos
            w1 = w1 + learning_rate * error * x1 # Actualización de peso w1
            w2 = w2 + learning_rate * error * x2 # Actualización de peso w2 
            b = b + learning_rate * error        # Actualización del bias b

        # Resumen por época
        print(f"Época {epoca:03d} | Errores: {errores_en_epoca}")
        
        # Criterio de parada        
        if errores_en_epoca == 0:
            print(f"Algoritmo de aprendizaje terminado por 0 errores en la época {epoca}.")
            return w1, w2, b  # devolvemos los valores en la época en la que los errores llegan a ser cero
        epoca = epoca + 1
    print(f'Devolvemos los valores w1, w2 y b después de {epocas} épocas')
    return w1, w2, b  # Devolvemos los parámetros aprendidos de w1, w2 y b

# %%
# Actividad 2
#Modifica el algoritmo de aprendizaje del Perceptrón. Utiliza un bucle while en lugar de un ciclo for para iterar sobre las
# diferentes líneas de la tabla (líneas del conjunto de datos X_test)
def entrenar_perceptron(X, y, epocas=100, learning_rate=0.1):
    # Entrena el perceptrón con:
    # X: lista de ejemplos (puntos) (cada ejemplo es una lista de características)
    # y: lista de etiquetas reales (0 o 1)
    # epocas: máximo de pasadas por el dataset
    # learning_rate: tamaño del paso de actualización (alpha)   

   
    m = len(X) # Número de puntos en la tabla (filas de X)
    n = len(X[0]) # Número de características, en este caso x1 y x2 son dos características por cada línea de X

    print("Filas:", m)
    print("Columnas:", n)

    
    # Inicialización aleatoria de w y b (valores pequeños).  Pesos iniciales    
    w1 = random.uniform(-0.5, 0.5)
    w2 = random.uniform(-0.5, 0.5)
    b = random.uniform(-0.5, 0.5)
    
    print("Pesos iniciales w:", w1, w2)
    print("Bias inicial b:", b)
    print("-" * 50)
    
    # Entrenamiento por épocas
    # ------------------------------------------------------------
    epoca = 0
    while epoca < epocas:
        errores_en_epoca = 0  # Contador de ejemplos mal clasificados en esta época

        # Recorremos los ejemplos (puntos-líneas de la tabla)
        k = 0
        while k < m:
            x1 = X[k][0]    # primer valor de la fila k de la columna 0 (la columna de los x1)
            x2 = X[k][1]    # segundo valor de la fila k de la columna 0 (la columna de los x1)
            y_real = y[k]   # Etiqueta real del ejemplo k
            
            y_pred = predecir(x1, x2, w1, w2, b) # Predicción actual (en esta época)
            
            error = y_real - y_pred              # Error (y real - y predicha)

            # Contamos si hubo error
            if error != 0:
                errores_en_epoca = errores_en_epoca + 1

            # Actualización de pesos
            w1 = w1 + learning_rate * error * x1 # Actualización de peso w1
            w2 = w2 + learning_rate * error * x2 # Actualización de peso w2 
            b = b + learning_rate * error        # Actualización del bias b
            k = k + 1

        # Resumen por época
        print(f"Época {epoca:03d} | Errores: {errores_en_epoca}")
        
        # Criterio de parada        
        if errores_en_epoca == 0:
            print(f"Algoritmo de aprendizaje terminado por 0 errores en la época {epoca}.")
            return w1, w2, b  # devolvemos los valores en la época en la que los errores llegan a ser cero
        epoca = epoca + 1
    print(f'Devolvemos los valores w1, w2 y b después de {epocas} épocas')
    return w1, w2, b  # Devolvemos los parámetros aprendidos de w1, w2 y b

# %%
# Actividad 3
# Modifica la función entrenar_perceptron(...) para que devuelva el número de épocas necesarias para entrenar el Perceptrón.
# Mediante una gráfica en Python, muestra como varía el número de épocas necesaria para el aprendizaje cuando la tasa de aprendizaje
# toma valores 0.1, 0.08, 0.06, 0.04, 0.02, 0.001. 
# Construye una tabla tasa de aprendizaje - epocas
# Utiliza la función plot(..) para dibujar la gráfica, con el número de épocas en el eje Y
# y las diferestes tasas de aprendizaje en el eje x. Escribe título de la gráfica, etiqueta para el eje x y etiqueta para el eje y.
def entrenar_perceptron(X, y, epocas=100, learning_rate=0.1):
    # Entrena el perceptrón con:
    # X: lista de ejemplos (puntos) (cada ejemplo es una lista de características)
    # y: lista de etiquetas reales (0 o 1)
    # epocas: máximo de pasadas por el dataset
    # learning_rate: tamaño del paso de actualización (alpha)   

   
    m = len(X) # Número de puntos en la tabla (filas de X)
    n = len(X[0]) # Número de características, en este caso x1 y x2 son dos características por cada línea de X

    print("Filas:", m)
    print("Columnas:", n)

    
    # Inicialización aleatoria de w y b (valores pequeños).  Pesos iniciales    
    w1 = random.uniform(-0.5, 0.5)
    w2 = random.uniform(-0.5, 0.5)
    b = random.uniform(-0.5, 0.5)
    
    print("Pesos iniciales w:", w1, w2)
    print("Bias inicial b:", b)
    print("-" * 50)
    
    # Entrenamiento por épocas
    # ------------------------------------------------------------
    epoca = 0
    while epoca < epocas:
        errores_en_epoca = 0  # Contador de ejemplos mal clasificados en esta época

        # Recorremos los ejemplos (puntos-líneas de la tabla)
        k = 0
        while k < m:
            x1 = X[k][0]    # primer valor de la fila k de la columna 0 (la columna de los x1)
            x2 = X[k][1]    # segundo valor de la fila k de la columna 0 (la columna de los x1)
            y_real = y[k]   # Etiqueta real del ejemplo k
            
            y_pred = predecir(x1, x2, w1, w2, b) # Predicción actual (en esta época)
            
            error = y_real - y_pred              # Error (y real - y predicha)

            # Contamos si hubo error
            if error != 0:
                errores_en_epoca = errores_en_epoca + 1

            # Actualización de pesos
            w1 = w1 + learning_rate * error * x1 # Actualización de peso w1
            w2 = w2 + learning_rate * error * x2 # Actualización de peso w2 
            b = b + learning_rate * error        # Actualización del bias b
            k = k + 1

        # Resumen por época
        print(f"Época {epoca:03d} | Errores: {errores_en_epoca}")
        
        # Criterio de parada        
        if errores_en_epoca == 0:
            epocas_necesarias = epoca + 1
            return w1, w2, b, epocas_necesarias

        epoca = epoca + 1

    # Si no converge antes, devolvemos el máximo configurado
    return w1, w2, b, epocas

# Tasas de aprendizaje
tasas_aprendizaje = [0.1, 0.08, 0.06, 0.04, 0.02, 0.001]
epocas_por_tasa = []

# Comparamos tasas manteniendo la misma semilla inicial
for tasa in tasas_aprendizaje:
    random.seed(42)
    _, _, _, epocas_necesarias = entrenar_perceptron(
        X_train, y_train, epocas=300, learning_rate=tasa
    )
    epocas_por_tasa.append(epocas_necesarias)

# Tabla tasa de aprendizaje - épocas
print("Tabla: tasa de aprendizaje - épocas")
print("Tasa\tÉpocas")
for tasa, ep in zip(tasas_aprendizaje, epocas_por_tasa):
    print(f"{tasa}\t{ep}")

# Gráfica con plot(..): Y=épocas, X=tasas
plt.figure(figsize=(8, 5))
plt.plot(tasas_aprendizaje, epocas_por_tasa, marker="o", linestyle="-")
plt.title("Variación del número de épocas según la tasa de aprendizaje")
plt.xlabel("Tasa de aprendizaje")
plt.ylabel("Número de épocas")
plt.grid(True)
plt.show()
# Out:
# Filas: 80
# Columnas: 2
# Pesos iniciales w: 0.13942679845788375 -0.47498924477733306
# Bias inicial b: -0.22497068163088074
# --------------------------------------------------
# Época 000 | Errores: 47
# Época 001 | Errores: 34
# Época 002 | Errores: 17
# Época 003 | Errores: 15
# Época 004 | Errores: 19
# Época 005 | Errores: 15
# Época 006 | Errores: 15
# Época 007 | Errores: 19
# Época 008 | Errores: 6
# Época 009 | Errores: 2
# Época 010 | Errores: 15
# Época 011 | Errores: 8
# Época 012 | Errores: 13
# Época 013 | Errores: 6
# Época 014 | Errores: 2
# Época 015 | Errores: 4
# Época 016 | Errores: 13
# Época 017 | Errores: 6
# Época 018 | Errores: 2
# Época 019 | Errores: 2
# Época 020 | Errores: 4
# Época 021 | Errores: 2
# Época 022 | Errores: 2
# Época 023 | Errores: 2
# Época 024 | Errores: 4
# Época 025 | Errores: 2
# Época 026 | Errores: 4
# Época 027 | Errores: 2
# Época 028 | Errores: 2
# Época 029 | Errores: 0
# Filas: 80
# Columnas: 2
# ...

# %%
# Actividad 4
# Utiliza la tabla anterior y, mediante la función plot(..), dibuja una gráfica, con el número de épocas en el eje Y
# y las diferentes tasas de aprendizaje en el eje x. Escribe título de la gráfica, etiqueta para el eje x y etiqueta para el eje y.

plt.figure(figsize=(8, 5))
plt.plot(tasas_aprendizaje, epocas_por_tasa, marker="o", linestyle="-")
plt.title("Variación del número de épocas según la tasa de aprendizaje")
plt.xlabel("Tasa de aprendizaje")
plt.ylabel("Número de épocas")
plt.grid(True)
plt.show()

# %%
# Actividad 5
# Utiliza la función plot(..) para dibujar la gráfica, con el número de épocas en el eje Y
# y las diferestes tasas de aprendizaje en el eje x. Escribe título de la gráfica, etiqueta para el eje x y etiqueta para el eje y.
plt.figure(figsize=(8, 5))
plt.plot(tasas_aprendizaje, epocas_por_tasa, marker="o", linestyle="-")
plt.title("Variación del número de épocas según la tasa de aprendizaje")
plt.xlabel("Tasa de aprendizaje")
plt.ylabel("Número de épocas")
plt.grid(True)
plt.show()

# %%
# Actividad 6.
# Modifica la función encontrar_recta_separa_grupos(..) adecuadamente e intégrala dentro de la función entrenar_perceptron(..)
# para que dibuje los puntos del conjunto de entrenamiento y, en cada época, dibuje la recta con los parámetros w1, w2 y b de esa época.
def encontrar_recta_separa_grupos(X, w1, w2, b):
    plt.figure(figsize=(10, 10))

    x = [p[0] for p in X]
    y = [p[1] for p in X]  
   

    # Dibujamos cada grupo con distinto color y marcador
    plt.plot(x, y, 'o', markersize=3)

    # Dibuja la recta w1*x1 + w2*x2 + b = 0    
   
    # Creamos valores de x1 (eje horizontal)    np.linspace genera puntos entre -10 y 10
    x1 = np.linspace(-8, 8, 200)

    # Despejamos y de la ecuación:   w1*x1 + w2*x2 + b = 0  ->  x2 = -(w1*x1 + b)/w2 y  w2 != 0
    x2 = -(w1/w2) * x1 - (b/w2)

    # Origen: corte con eje y
    x_origen = 0
    y_origen = -b / w2
    
    plt.plot(x1, x2, color="red")
    # dibujamos el vector w = (w1, w2) desde un punto de la recta (0, -b/w2)
    plt.quiver(x_origen, y_origen,                 # (0,-b/w2) origen del vector
               w1, w2,                   # componentes del vector. Indican su dirección y magnitud
               angles="xy",              # el vector se dibuja con su dirección real en el plano
               scale_units="xy",         # la escala del vector se mide en las mismas unidades de los ejes x e y
               scale=1,                  # longitud “normal”. Cuanto más pequeño es scale más grande es la flecha
               color='red'               # color de la flecha
              )
    plt.text(2, 2, " x", fontsize=12, color="black")
    
   # Origen: corte con eje y
    x_origen = 0
    y_origen = -b / w2

    # Vector azul hacia el punto (0.8, 0.8)
    px1, py1 = 1.8, 1
    plt.quiver(x_origen, y_origen,
           px1 - x_origen, py1 - y_origen,
           angles="xy",
           scale_units="xy",
           scale=1,
           color='blue')

    # Vector naranja hacia el punto (6, 4.5)
    px2, py2 = 4.5, 3.5
    plt.quiver(x_origen, y_origen,
           px2 - x_origen, py2 - y_origen,
           angles="xy",
           scale_units="xy",
           scale=1,
           color='orange')
    plt.text(w1, w2, " w", fontsize=12, color="red")
    
    # Dibujamos los ejes coordenados
    plt.axhline(0)   # eje x1
    plt.axvline(0)   # eje x2

    # Leyendas
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(
        f'Recta: ${w1}x_1 + {w2}x_2 + ({b}) = 0$'
    )
    #plt.title(r"Gráfica recta $w_1 x_1 + w_2 x_2 + b = 0$")
    plt.grid(True)

    plt.xlim(-8, 8) # definimos rango del eje x
    plt.ylim(-8, 8) # definimos rango del eje y
   
    #plt.legend() # mostramos la leyenda que identifica cada grupo
    # Etiquetas cerca de la punta de cada vector 
    # Mostramos la figura en pantalla
    # plt.pause(0.5) # Pausa para mostrar la figura antes de cerrarla, lo cual permite que imprima varios gráficos.
    plt.pause(0.5)
    plt.close()

def entrenar_perceptron(X, y, epocas=100, learning_rate=0.1):
    # Entrena el perceptrón con:
    # X: lista de ejemplos (puntos) (cada ejemplo es una lista de características)
    # y: lista de etiquetas reales (0 o 1)
    # epocas: máximo de pasadas por el dataset
    # learning_rate: tamaño del paso de actualización (alpha)   

   
    m = len(X) # Número de puntos en la tabla (filas de X)
    n = len(X[0]) # Número de características, en este caso x1 y x2 son dos características por cada línea de X

    print("Filas:", m)
    print("Columnas:", n)

    
    # Inicialización aleatoria de w y b (valores pequeños).  Pesos iniciales    
    w1 = random.uniform(-0.5, 0.5)
    w2 = random.uniform(-0.5, 0.5)
    b = random.uniform(-0.5, 0.5)
    
    print("Pesos iniciales w:", w1, w2)
    print("Bias inicial b:", b)
    print("-" * 50)
    
    # Entrenamiento por épocas
    # ------------------------------------------------------------
    epoca = 0
    while epoca < epocas:
        errores_en_epoca = 0  # Contador de ejemplos mal clasificados en esta época

        # Recorremos los ejemplos (puntos-líneas de la tabla)
        k = 0
        while k < m:
            x1 = X[k][0]    # primer valor de la fila k de la columna 0 (la columna de los x1)
            x2 = X[k][1]    # segundo valor de la fila k de la columna 0 (la columna de los x1)
            y_real = y[k]   # Etiqueta real del ejemplo k
            
            y_pred = predecir(x1, x2, w1, w2, b) # Predicción actual (en esta época)
            
            error = y_real - y_pred              # Error (y real - y predicha)

            # Contamos si hubo error
            if error != 0:
                errores_en_epoca = errores_en_epoca + 1

            # Actualización de pesos
            w1 = w1 + learning_rate * error * x1 # Actualización de peso w1
            w2 = w2 + learning_rate * error * x2 # Actualización de peso w2 
            b = b + learning_rate * error        # Actualización del bias b
            k = k + 1

        # Resumen por época
        print(f"Época {epoca:03d} | Errores: {errores_en_epoca}")
        
        encontrar_recta_separa_grupos(X, w1, w2, b)
        
        # Criterio de parada        
        if errores_en_epoca == 0:
            print(f"Algoritmo de aprendizaje terminado por 0 errores en la época {epoca}.")
            return w1, w2, b  # devolvemos los valores en la época en la que los errores llegan a ser cero
        epoca = epoca + 1
    print(f'Devolvemos los valores w1, w2 y b después de {epocas} épocas')
    return w1, w2, b  # Devolvemos los parámetros aprendidos de w1, w2 y b

w1, w2, b = entrenar_perceptron(X_train, y_train, epocas=100, learning_rate=0.1)
# Out:
# Filas: 80
# Columnas: 2
# Pesos iniciales w: -0.27678926185117725 0.2364712141640124
# Bias inicial b: 0.1766994874229113
# --------------------------------------------------
# Época 000 | Errores: 33
# Época 001 | Errores: 0
# Algoritmo de aprendizaje terminado por 0 errores en la época 1.
