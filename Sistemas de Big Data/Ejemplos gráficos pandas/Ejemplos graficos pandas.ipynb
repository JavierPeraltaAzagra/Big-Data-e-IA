# %% [markdown]
# # Ejemplos gráficos pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fish.csv')

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# Cuántos valores hay de cada especie.

# %%
vc = df["Species"].value_counts()
vc
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %% [markdown]
# Cuántos valores hay de cada especie en gráfico de barras.

# %%
ax = vc.plot(kind="bar")

# %% [markdown]
# Peso por especie.

# %%
#order = df.groupby("Species")["Weight"].median().sort_values().index
#data = [df.loc[df["Species"] == s, "Weight"] for s in order]
x = df["Length1"]
y = df["Weight"]
plt.scatter(x, y)
plt.xlabel("Longitud 1")
plt.ylabel("Peso")
# Out:
# Text(0, 0.5, 'Peso')
